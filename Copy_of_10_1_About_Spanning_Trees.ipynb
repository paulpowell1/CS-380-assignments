# %% [markdown]
# <a href="https://colab.research.google.com/github/paulpowell1/CS-380-assignments/blob/main/Copy_of_10_1_About_Spanning_Trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 10_1_About_Spanning_Trees
# ## Divide Pair Conquer
# ### Due: Monday, 8 March 2021, 11:59 pm

# %% [markdown]
# ## Trees and Graphs

# %% [markdown]
# Let's start looking at trees in a graph context:

# %% [markdown]
# ### General Properties

# %% [markdown]
# Trees are graphs with constraints:
# 1. No cycles
# 2. Connected

# %% [markdown]
# ### Spanning Trees and Ladder Graphs

# %% [markdown]
# #### A Spanning Tree Example

# %% [markdown]
# ![spanning-tree.png](data:image/png;base64,...)

# %% [markdown]
# #### Ladder Graph (AKA 2xN Grid)

# %% [markdown]
# ![ladder-graph.png](data:image/png;base64,...)

# %% [markdown]
# ## TODO Answer Two Questions

# %% [markdown]
# ### Question 1

# %% [markdown]
# How many spanning trees does an n-rung ladder graph have?

# %% [markdown]
# 55
#
# Using Cayley's formula n^(n-2) it is 16 but I don't think that is correct. i tried writing it out manualy to see if it was 55 but ended up confusing myself.

# %% [markdown]
# | n | NST(n) |
# |---|--------|
# | 1 | 1      |
# | 2 | 4      |
# | 3 | 15     |
# | 4 | 55     |
#
# What is the formula for computing NST(n) in general?

# %% [markdown]
# NST (Gt) = y1x2x3 + y2x1x3 + y3x1x2.... this is according to https://core.ac.uk/download/pdf/82777981.pdf which is part of the proof on page 4578

# %% [markdown]
# ### Question 2

# %% [markdown]
# How many of these spanning trees include the bottom rung?

# %% [markdown]
# | n | NSTIBR(n) |
# |---|-----------|
# | 1 | 1         |
# | 2 | 3         |
# | 3 | 11        |
# | 4 | 47        |
#
# What is the formula for computing NSTIBR(n) in general?

# %% [markdown]
# ![image.png](data:image/png;base64,...)
